# %%
import bar_chart_race as bcr
import pandas as pd

# %%
df = pd.read_csv('motogp-2020-championship-standing.csv')
df = df.set_index('race')

# %%
df
# Out:
#        race  Joan Mir  Franco Morbidelli  Alex Rins  Andrea Dovizioso  \
# 0    race 1         0                 11          0                16
# 1    race 2        11                 11          6                26
# 2    race 3        11                 31         19                31
# 3    race 4        31                 31         19                56
# 4    race 5        44                 32         29                67
# 5    race 6        60                 57         40                76
# 6    race 7        80                 64         44                84
# 7    race 8       100                 77         60                84
# 8    race 9       105                 77         60                97
# 9   race 10       121                 87         85               106
# 10  race 11       137                112        105               109
# 11  race 12       162                117        125               117
# ...

# %%
bcr.bar_chart_race(
    df=df, 
    title='2020 MotoGP Championship Race', 
    orientation='h', 
    sort='desc', 
    n_bars=10, 
    steps_per_period=40, 
    period_length=2000
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/bar_chart_race/_make_chart.py:889: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_values.iloc[:, 0] = df_values.iloc[:, 0].fillna(method='ffill')
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/bar_chart_race/_make_chart.py:286: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(self.df_values.columns)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/bar_chart_race/_make_chart.py:287: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# ---------------------------------------------------------------------------
# ...
